# %%
members_number = []

for i in range(1, 31):
    members_number.append(i)

for j in range(28):
    a = int(input())
    members_number.remove(a)
print(members_number[0])
print(members_number[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       6 for j in range(28):
#       7     a = int(input())
# ----> 8     members_number.remove(a)
#       9 print(*members_number[0])
#      10 print(*members_number[1])
#
# ValueError: list.remove(x): x not in list
