# %%
up, down, target_height = map(int, input().split())

height = 0
count = 0


while True:
    count += 1
    height += up
    if height >= target_height:
        break
    height -= down
print(count)

# %%
import math

up, down, target_height = map(int, input().split())

height = 0
days = 0

days = math.ceil((target_height - up) / (up - down)) + 1
print(days)
# Out:
# 999999901
