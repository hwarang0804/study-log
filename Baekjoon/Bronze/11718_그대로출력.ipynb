# %%
import sys

while True:
    a = input()
    if not a:
        break    
    print(a)
# Out:
# Hello

# %%
while True:
    try:
        a = input()
    except EOFError:
        break 
    print(a)
# Out:
# Hello
# in
# 9
