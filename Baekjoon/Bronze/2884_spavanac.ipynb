# %%
H, M = map(int, input().split())

resultM = M - 45

if resultM >= 0:
    print(H, resultM)
elif resultM < 0:
    if H - 1 >= 0:
        print(H - 1, resultM + 60)
    else:
        print(H + 23, resultM + 60)
# Out:
# 19 65
