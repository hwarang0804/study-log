# %%
alpabet = input()

kuroatia = {   
    "c=" : 1,
    "c-" : 1,
    "dz=" : 1,
    "d-" : 1,
    "lj" : 1,
    "nj" : 1,
    "s=" : 1,
    "z=" : 1
}


for i in kuroatia:
    alpabet = alpabet.replace(i, "*")

print(len(alpabet))
# Out:
# 6
