# %%
boxs = []

N, M = map(int, input().split())

for b in range(N):
    boxs.append(b + 1)

for a in range(M):
    i, j = map(int, input().split())

    boxs[i - 1], boxs[j - 1] = boxs[j - 1], boxs[i - 1]
print(*boxs)
# Out:
# 3 1 4 2 5
