# %%
A, B, C = map(int, input().split())

if A == B and A == C and B == C:
    print(10000 + A * 1000)
elif A == B or A == C or B == C:
    if A == B or A == C:
        print(1000 + A * 100)
    else:
        print(1000 + B * 100)
else:
    maxNumber = max(A, B, C)
    print(maxNumber * 100)
# Out:
# 600

# %%
A = 1
B = 2
m = [A, B]
max(A, B)
# Out:
# 2
