# %%
print('''         ,r'"7
r`-_   ,'  ,/
 \. ". L_r'
   `~\/
      |
      |''')
# Out:
#          ,r'"7
# r`-_   ,'  ,/
#  \. ". L_r'
#    `~\/
#       |
#       |
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\82103\AppData\Local\Temp\ipykernel_31164\470556367.py:3: SyntaxWarning: invalid escape sequence '\.'
#   \. ". L_r'

# %%
print('''asdfasdfas
asdfasdf
asdfasdf
asdfsdfdsfddgalsgjsd''')
# Out:
# asdfasdfas
# asdfasdf
# asdfasdf
# asdfsdfdsfddgalsgjsd
