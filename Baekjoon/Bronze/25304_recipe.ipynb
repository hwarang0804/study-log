# %%
totalPrice = int(input())
N = int(input())
i = 0
sum = 0

while i < N: 
    price, number = map(int, input().split())
    sum = sum + (price * number)
    i += 1
if totalPrice == sum:
    print("Yes")
else:
    print("No")
# Out:
# Yes
