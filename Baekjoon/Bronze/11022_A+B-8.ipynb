# %%
n = int(input())
i = 0

while i < n:
    A, B = map(int, input().split())
    sum = A + B
    print(f"Case #{i + 1}: {A} + {B} = {sum}")
    i += 1
# Out:
# Case #1: 1 + 1 = 2
# Case #2: 2 + 3 = 5
# Case #3: 3 + 4 = 7
# Case #4: 9 + 8 = 17
# Case #5: 5 + 2 = 7
