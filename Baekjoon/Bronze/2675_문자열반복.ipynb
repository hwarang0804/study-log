# %%
T = int(input())

for i in range(T):
    N, string = map(str, input().split())
    N = int(N)
    for j in range(len(string)):
        print(string[j] * N, end = "")
    print()
# Out:
# AAABBBCCC
# /////HHHHHTTTTTPPPPP
