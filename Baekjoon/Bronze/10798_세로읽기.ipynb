# %%
matrix = []

for _ in range(5):
    matrix.append(input())

for i in range(15):
    for j in range(5):
        if len(matrix[j]) > i:
            print(matrix[j][i], end="")
# Out:
# Aa0aPAf985Bz1EhCz2W3
