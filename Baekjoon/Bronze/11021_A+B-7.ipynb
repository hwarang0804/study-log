# %%
n = int(input())
i = 0

while i < n:
    A, B = map(int, input().split())
    sum = A + B
    print(f"Case #{i + 1}: {sum}")
    i += 1
# Out:
# Case #1: 2
# Case #2: 5
# Case #3: 7
# Case #4: 17
# Case #5: 7
